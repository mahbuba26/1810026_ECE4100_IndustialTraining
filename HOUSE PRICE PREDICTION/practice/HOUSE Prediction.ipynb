# %%
# !pip install seaborn
# !pip install scikit-learn
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      -------- ------------------------------ 61.4/293.3 kB 1.1 MB/s eta 0:00:01
#      ----------------- -------------------- 133.1/293.3 kB 1.1 MB/s eta 0:00:01
#      ------------------------------- ------ 245.8/293.3 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      - -------------------------------------- 0.3/7.6 MB 6.1 MB/s eta 0:00:02
#      - -------------------------------------- 0.4/7.6 MB 4.7 MB/s eta 0:00:02
#      --- ------------------------------------ 0.6/7.6 MB 4.0 MB/s eta 0:00:02
#      --- ------------------------------------ 0.7/7.6 MB 4.2 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.8/7.6 MB 3.6 MB/s eta 0:00:02
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets

# %%
train=pd.read_csv('C:/Users/Lenovo/MACHINE LEARNING/house predictions/train.csv')
test=pd.read_csv('C:/Users/Lenovo/MACHINE LEARNING/house predictions/test.csv')
submission=pd.read_csv('C:/Users/Lenovo/MACHINE LEARNING/house predictions/sample_submission.csv')

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, LotFrontage, LotArea, SalePrice]
# Index: []

# %%
train['SalePrice'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
train.isnull().sum()
# Out:
# Id               0.0
# MSSubClass       0.0
# MSZoning         0.0
# LotFrontage      0.0
# LotArea          0.0
#                 ...
# MoSold           0.0
# YrSold           0.0
# SaleType         0.0
# SaleCondition    0.0
# SalePrice        0.0
# Length: 81, dtype: float64

# %% [raw]
# train = train.loc[:, df.columns.intersection(['Id','MSSubClass','LotFrontage','LotArea','SalePrice'])]

# %%
train = train.loc[:, train.columns.intersection(['Id','MSSubClass','LotFrontage','LotArea','SalePrice'])]

# %%
train
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, LotFrontage, LotArea, SalePrice]
# Index: []
